# %%
import polars as pl

# %%
data = pl.read_csv('data/ICPSR_20541/DS0001/20541-0001-Data.tsv', separator='\t')

# %%
data.head()
# Out:
# shape: (5, 820)
# ┌────────┬────────┬──────┬─────────┬───┬─────────┬──────────┬──────────┬─────────┐
# │ ID     ┆ FI_ID  ┆ PATH ┆ VERSION ┆ … ┆ OTBUILD ┆ COMBUILD ┆ CASECOMP ┆ CASEDIF │
# │ ---    ┆ ---    ┆ ---  ┆ ---     ┆   ┆ ---     ┆ ---      ┆ ---      ┆ ---     │
# │ i64    ┆ i64    ┆ i64  ┆ i64     ┆   ┆ i64     ┆ i64      ┆ i64      ┆ i64     │
# ╞════════╪════════╪══════╪═════════╪═══╪═════════╪══════════╪══════════╪═════════╡
# │ 100005 ┆ 866808 ┆ 1    ┆ 1       ┆ … ┆ 3       ┆ 3        ┆ 11       ┆ 2       │
# │ 100033 ┆ 169164 ┆ 3    ┆ 3       ┆ … ┆ 3       ┆ 4        ┆ 11       ┆ 3       │
# │ 100080 ┆ 281481 ┆ 6    ┆ 2       ┆ … ┆ 3       ┆ 3        ┆ 11       ┆ 4       │
# │ 100154 ┆ 24499  ┆ 4    ┆ 3       ┆ … ┆ 3       ┆ 3        ┆ 11       ┆ 3       │
# │ 100203 ┆ 289103 ┆ 3    ┆ 3       ┆ … ┆ 4       ┆ 3        ┆ 11       ┆ 2       │
# └────────┴────────┴──────┴─────────┴───┴─────────┴──────────┴──────────┴─────────┘
